# %%
import pandas as pd

df=pd.read_csv("/content/sentiment_analysis.csv")

# %% [markdown]
# #Different Loading Methods

# %%
import pandas as pd

excel_df = pd.read_excel('your_excel_file.xlsx')
print("Excel data loaded successfully:")

json_df = pd.read_json('your_json_file.json')
print("JSON data loaded successfully:")

txt_df = pd.read_txt('your_text_file.txt', sep=',')
print("TXT data loaded successfully (as DataFrame):")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-87882474.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 excel_df = pd.read_excel('your_excel_file.xlsx')
#       4 print("Excel data loaded successfully:")
#       5
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/excel/_base.py in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493     if not isinstance(io, ExcelFile):
#     494         should_close = True
# --> 495         io = ExcelFile(
#     496             io,
#     497             storage_options=storage_options,
#
# ...

# %% [markdown]
# #Manual Dataframe

# %%
data = {
    "text": [
        "I love NLP",
        "NLP is powerful",
        "Text data is messy"
    ],

    "labels":[
        "positive",
        "positive",
        "negative"
    ]
}

data = pd.DataFrame(data)

data.head()
# Out:
#                  text    labels
# 0          I love NLP  positive
# 1     NLP is powerful  positive
# 2  Text data is messy  negative

# %%
df.head(10)
# Out:
#    Year  Month  Day Time of Tweet  \
# 0  2018      8   18       morning
# 1  2018      8   18          noon
# 2  2017      8   18         night
# 3  2022      6    8       morning
# 4  2022      6    8          noon
# 5  2016     11   22         night
# 6  2017     12   28       morning
# 7  2017     12   28          noon
# 8  2019     10   28         night
# 9  2018      5   28       morning
#
#                                                 text sentiment     Platform
# 0              What a great day!!! Looks like dream.  positive    Twitter
# 1     I feel sorry, I miss you here in the sea beach  positive    Facebook
# 2                                     Don't angry me  negative     Facebook
# 3  We attend in the class just for listening teac...  negative    Facebook
# 4                  Those who want to go, let them go  negative   Instagram
# 5                    Its night 2 am, feeling neutral   neutral     Facebook
# ...

# %%
df.tail(25)
# Out:
#      Year  Month  Day Time of Tweet  \
# 474  2023      1   15       morning
# 475  2023      1   18          noon
# 476  2016     11   28         night
# 477  2021     10    2       morning
# 478  2022     11   28          noon
# 479  2022      7    5         night
# 480  2016      9   28       morning
# 481  2021      9   15          noon
# 482  2022      2   28         night
# 483  2023      1   16       morning
# 484  2018     11    7          noon
# 485  2017      3   20         night
# 486  2023      3   22       morning
# 487  2018      7   10          noon
# 488  2021     11   30         night
# 489  2021     11   30       morning
# 490  2023      1   22          noon
# 491  2023      1   24         night
# 492  2023      1   27       morning
# 493  2023      3    3          noon
# 494  2015     10   18         night
# 495  2021      2   25       morning
# 496  2022      5   30          noon
# 497  2018      8   10         night
# 498  2019      3   25       morning
#
# ...

# %%
df.shape
# Out:
# (499, 7)

# %%
df.columns
# Out:
# Index(['Year', 'Month', 'Day', 'Time of Tweet', 'text', 'sentiment',
#        'Platform'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 499 entries, 0 to 498
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Year           499 non-null    int64
#  1   Month          499 non-null    int64
#  2   Day            499 non-null    int64
#  3   Time of Tweet  499 non-null    object
#  4   text           499 non-null    object
#  5   sentiment      499 non-null    object
#  6   Platform       499 non-null    object
# dtypes: int64(3), object(4)
# memory usage: 27.4+ KB

# %%
# df1=df.copy()

# %%
columns_to_drop = ['Year', 'Month', 'Day', 'Time of Tweet', 'Platform']
df = df.drop(columns=columns_to_drop)

# %%
df.head()
# Out:
#                                                 text sentiment
# 0              What a great day!!! Looks like dream.  positive
# 1     I feel sorry, I miss you here in the sea beach  positive
# 2                                     Don't angry me  negative
# 3  We attend in the class just for listening teac...  negative
# 4                  Those who want to go, let them go  negative

# %%
df.shape
# Out:
# (499, 2)

# %% [markdown]
# #loc/iloc

# %%
data = {
    "Name" :[" Kabir" , "Polash " , "Imran" , "Mahmuda"],
    "Age" : [21,22,23,24],
    "CGPA" : [3.9,3.4,4,3.2]
}

# %%
data1 = pd.DataFrame(data)

# %%
data1.head()
# Out:
#       Name  Age  CGPA
# 0    Kabir   21   3.9
# 1  Polash    22   3.4
# 2    Imran   23   4.0
# 3  Mahmuda   24   3.2

# %%
data1.loc[1]
# Out:
# Name    Polash
# Age          22
# CGPA        3.4
# Name: 1, dtype: object

# %%
data1.loc[1:3]
# Out:
#       Name  Age  CGPA
# 1  Polash    22   3.4
# 2    Imran   23   4.0
# 3  Mahmuda   24   3.2

# %%
data2=data1.loc[:, ["Name" , "CGPA"]]

# %%
data2
# Out:
#       Name  CGPA
# 0    Kabir   3.9
# 1  Polash    3.4
# 2    Imran   4.0
# 3  Mahmuda   3.2

# %%
data1.loc[data1["CGPA"] > 3.5]
# Out:
#      Name  Age  CGPA
# 0   Kabir   21   3.9
# 2   Imran   23   4.0

# %%
data1.iloc[1:3]
# Out:
#       Name  Age  CGPA
# 1  Polash    22   3.4
# 2    Imran   23   4.0

# %% [markdown]
# #NLP Feature Engineering

# %% [markdown]
# accessing individual column

# %%
df["word_count"] = df["text"].apply(lambda x: len(x.split()))

df["word_count"]
# Out:
# 0       7
# 1      11
# 2       3
# 3      14
# 4       8
#        ..
# 494    12
# 495    10
# 496     7
# 497    12
# 498    12
# Name: word_count, Length: 499, dtype: int64

# %%
df.head()
# Out:
#                                                 text sentiment  word_count
# 0              What a great day!!! Looks like dream.  positive           7
# 1     I feel sorry, I miss you here in the sea beach  positive          11
# 2                                     Don't angry me  negative           3
# 3  We attend in the class just for listening teac...  negative          14
# 4                  Those who want to go, let them go  negative           8

# %%
df["char_count"] = df["text"].apply(len)

# %%
df
# Out:
#                                                   text sentiment  word_count  \
# 0                What a great day!!! Looks like dream.  positive           7
# 1       I feel sorry, I miss you here in the sea beach  positive          11
# 2                                       Don't angry me  negative           3
# 3    We attend in the class just for listening teac...  negative          14
# 4                    Those who want to go, let them go  negative           8
# ..                                                 ...       ...         ...
# 494  According to , a quarter of families under six...  negative          12
# 495      the plan to not spend money is not going well  negative          10
# 496    uploading all my bamboozle pictures of facebook   neutral           7
# 497   congratulations ! you guys finish a month ear...  positive          12
# 498   actually, I wish I was back in Tahoe.  I miss...  negative          12
#
#      char_count
# 0            37
# ...

# %%
len("Name ")
# Out:
# 5

# %% [markdown]
# Longest Word

# %%
df.loc[df["word_count"].idxmax()]
# Out:
# text          The pics I just uploaded are the baby pics of ...
# sentiment                                               neutral
# word_count                                                   29
# char_count                                                  137
# Name: 303, dtype: object

# %%
df.loc[df["word_count"].idxmin()]
# Out:
# text          MAYDAY?!
# sentiment      neutral
# word_count           1
# char_count           8
# Name: 42, dtype: object

# %%
df["word_count"].hist()
# Out:
# <Axes: >

# %%
from collections import Counter

all_words = " ".join(df["text"]).split()
word_freq = Counter(all_words)

word_freq.most_common(10)
# Out:
# [('to', 179),
#  ('I', 165),
#  ('the', 132),
#  ('a', 97),
#  ('and', 88),
#  ('my', 87),
#  ('you', 85),
#  ('for', 74),
#  ('is', 65),
#  ('in', 62)]

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

text = " ".join(df["text"])

wc = WordCloud(width=800, height=400, background_color="white").generate(text)

plt.imshow(wc)
plt.axis("off")
# Out:
# (np.float64(-0.5), np.float64(799.5), np.float64(399.5), np.float64(-0.5))
